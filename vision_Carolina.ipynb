# %%
import boto3
import os

os.environ["AWS_ACCESS_KEY_ID"] = "XXXXXXXXXXXXX"
os.environ["AWS_SECRET_ACCESS_KEY"] = "XXXXXXXXXXXXXx"
os.environ["AWS_DEFAULT_REGION"] = "us-east-1"

def detect_text_in_image(image_bytes):
    """
    Detecta texto en una imagen usando Amazon Rekognition.

    +
    Parámetros:
    - image_bytes: Contenido de la imagen en bytes.
    
    Retorna:
    - Lista de textos detectados con sus coordenadas.
    """
    # Crear cliente de Rekognition
    rekognition_client = boto3.client('rekognition')

    # Llamar a DetectText
    response = rekognition_client.detect_text(
        Image={'Bytes': image_bytes}
    )

    # Extraer texto detectado
    detected_texts = []
    for item in response['TextDetections']:
        detected_texts.append({
            "Texto": item['DetectedText'],
            "Confianza": item['Confidence'],
            "Tipo": item['Type'],  # 'LINE' o 'WORD'
            "Coordenadas": item['Geometry']['BoundingBox']
        })

    return detected_texts

# Leer imagen y ejecutar detección
image_path = "foto_marquesina.jpg"  # Ruta de la imagen
with open(image_path, "rb") as image_file:
    image_bytes = image_file.read()

# Detectar texto
result = detect_text_in_image(image_bytes)

# Imprimir resultado
for text in result:
    print(f"Texto: {text['Texto']} - Confianza: {text['Confianza']:.2f}% - Tipo: {text['Tipo']}")
# Out:
# Texto: COLOMBIA - Confianza: 98.79% - Tipo: LINE
# Texto: POTENCIA DE LA - Confianza: 98.80% - Tipo: LINE
# Texto: TIC - Confianza: 100.00% - Tipo: LINE
# Texto: VIDA - Confianza: 100.00% - Tipo: LINE
# Texto: INTELIGENCIA - Confianza: 99.60% - Tipo: LINE
# Texto: ARTIFICIAL - Confianza: 99.25% - Tipo: LINE
# Texto: ¡Ya vienen las pruebas - Confianza: 98.76% - Tipo: LINE
# Texto: de conocimiento! - Confianza: 96.80% - Tipo: LINE
# Texto: EDUCA - Confianza: 99.16% - Tipo: LINE
# Texto: 16, 17 y 18 de diciembre - Confianza: 99.26% - Tipo: LINE
# Texto: TECH - Confianza: 71.15% - Tipo: LINE
# Texto: TALENTO - Confianza: 98.36% - Tipo: LINE
# Texto: COLOMBIA - Confianza: 98.79% - Tipo: WORD
# Texto: POTENCIA - Confianza: 97.48% - Tipo: WORD
# Texto: DE - Confianza: 99.28% - Tipo: WORD
# Texto: LA - Confianza: 99.63% - Tipo: WORD
# Texto: TIC - Confianza: 100.00% - Tipo: WORD
# Texto: VIDA - Confianza: 100.00% - Tipo: WORD
# Texto: INTELIGENCIA - Confianza: 99.60% - Tipo: WORD
# Texto: ARTIFICIAL - Confianza: 99.25% - Tipo: WORD
# Texto: ¡Ya - Confianza: 99.78% - Tipo: WORD
# Texto: vienen - Confianza: 96.29% - Tipo: WORD
# Texto: las - Confianza: 99.80% - Tipo: WORD
# Texto: pruebas - Confianza: 99.17% - Tipo: WORD
# Texto: de - Confianza: 100.00% - Tipo: WORD
# Texto: conocimiento! - Confianza: 93.61% - Tipo: WORD
# Texto: EDUCA - Confianza: 99.16% - Tipo: WORD
# Texto: 16, - Confianza: 100.00% - Tipo: WORD
# Texto: 17 - Confianza: 100.00% - Tipo: WORD
# Texto: y - Confianza: 95.99% - Tipo: WORD
# Texto: 18 - Confianza: 100.00% - Tipo: WORD
# Texto: de - Confianza: 100.00% - Tipo: WORD
# Texto: diciembre - Confianza: 99.60% - Tipo: WORD
# Texto: TECH - Confianza: 71.15% - Tipo: WORD
# Texto: TALENTO - Confianza: 98.36% - Tipo: WORD

# %%
for text in result:
    print(f"Texto: {text['Texto']} - Confianza: {text['Confianza']:.2f}% - Tipo: {text['Tipo']} - Coordenadas: {text['Coordenadas']}")
# Out:
# Texto: COLOMBIA - Confianza: 98.79% - Tipo: LINE - Coordenadas: {'Width': 0.0668402761220932, 'Height': 0.0283203125, 'Left': 0.0889756977558136, 'Top': 0.0986328125}
# Texto: POTENCIA DE LA - Confianza: 98.80% - Tipo: LINE - Coordenadas: {'Width': 0.0655381977558136, 'Height': 0.017578125, 'Left': 0.0898437350988388, 'Top': 0.1298828125}
# Texto: TIC - Confianza: 100.00% - Tipo: LINE - Coordenadas: {'Width': 0.0533854179084301, 'Height': 0.05859375, 'Left': 0.9171006679534912, 'Top': 0.1142578125}
# Texto: VIDA - Confianza: 100.00% - Tipo: LINE - Coordenadas: {'Width': 0.0655381977558136, 'Height': 0.044921875, 'Left': 0.08984375, 'Top': 0.15234375}
# Texto: INTELIGENCIA - Confianza: 99.60% - Tipo: LINE - Coordenadas: {'Width': 0.0607638880610466, 'Height': 0.01953125, 'Left': 0.49609375, 'Top': 0.25}
# Texto: ARTIFICIAL - Confianza: 99.25% - Tipo: LINE - Coordenadas: {'Width': 0.0473090261220932, 'Height': 0.0205078125, 'Left': 0.5143229365348816, 'Top': 0.27734375}
# Texto: ¡Ya vienen las pruebas - Confianza: 98.76% - Tipo: LINE - Coordenadas: {'Width': 0.43828389048576355, 'Height': 0.14167337119579315, 'Left': 0.0675775334239006, 'Top': 0.2953489422798157}
# Texto: de conocimiento! - Confianza: 96.80% - Tipo: LINE - Coordenadas: {'Width': 0.33670973777770996, 'Height': 0.13221336901187897, 'Left': 0.11395277082920074, 'Top': 0.41017216444015503}
# Texto: EDUCA - Confianza: 99.16% - Tipo: LINE - Coordenadas: {'Width': 0.046875, 'Height': 0.02734375, 'Left': 0.9526909589767456, 'Top': 0.517578125}
# Texto: 16, 17 y 18 de diciembre - Confianza: 99.26% - Tipo: LINE - Coordenadas: {'Width': 0.2966732978820801, 'Height': 0.05997024476528168, 'Left': 0.12705789506435394, 'Top': 0.6188166737556458}
# Texto: TECH - Confianza: 71.15% - Tipo: LINE - Coordenadas: {'Width': 0.1944444477558136, 'Height': 0.1435546875, 'Left': 0.1792534738779068, 'Top': 0.7744140625}
# Texto: TALENTO - Confianza: 98.36% - Tipo: LINE - Coordenadas: {'Width': 0.1184895858168602, 'Height': 0.0380859375, 'Left': 0.1974826455116272, 'Top': 0.78125}
# Texto: COLOMBIA - Confianza: 98.79% - Tipo: WORD - Coordenadas: {'Width': 0.0668402761220932, 'Height': 0.0283203125, 'Left': 0.0889756977558136, 'Top': 0.0986328125}
# Texto: POTENCIA - Confianza: 97.48% - Tipo: WORD - Coordenadas: {'Width': 0.0412326380610466, 'Height': 0.017578125, 'Left': 0.08984375, 'Top': 0.1298828125}
# Texto: DE - Confianza: 99.28% - Tipo: WORD - Coordenadas: {'Width': 0.01171875, 'Height': 0.0166015625, 'Left': 0.1319444477558136, 'Top': 0.130859375}
# Texto: LA - Confianza: 99.63% - Tipo: WORD - Coordenadas: {'Width': 0.0108506940305233, 'Height': 0.0166015625, 'Left': 0.14453125, 'Top': 0.130859375}
# Texto: TIC - Confianza: 100.00% - Tipo: WORD - Coordenadas: {'Width': 0.0533854179084301, 'Height': 0.05859375, 'Left': 0.9171006679534912, 'Top': 0.1142578125}
# Texto: VIDA - Confianza: 100.00% - Tipo: WORD - Coordenadas: {'Width': 0.0655381977558136, 'Height': 0.044921875, 'Left': 0.08984375, 'Top': 0.15234375}
# Texto: INTELIGENCIA - Confianza: 99.60% - Tipo: WORD - Coordenadas: {'Width': 0.0607638880610466, 'Height': 0.01953125, 'Left': 0.49609375, 'Top': 0.25}
# Texto: ARTIFICIAL - Confianza: 99.25% - Tipo: WORD - Coordenadas: {'Width': 0.0473090261220932, 'Height': 0.0205078125, 'Left': 0.5143229365348816, 'Top': 0.27734375}
# Texto: ¡Ya - Confianza: 99.78% - Tipo: WORD - Coordenadas: {'Width': 0.059741243720054626, 'Height': 0.11307542771100998, 'Left': 0.06763136386871338, 'Top': 0.3034156560897827}
# Texto: vienen - Confianza: 96.29% - Tipo: WORD - Coordenadas: {'Width': 0.12436024844646454, 'Height': 0.09083349257707596, 'Left': 0.14267191290855408, 'Top': 0.3132779002189636}
# Texto: las - Confianza: 99.80% - Tipo: WORD - Coordenadas: {'Width': 0.056159261614084244, 'Height': 0.10359090566635132, 'Left': 0.2819748520851135, 'Top': 0.30877014994621277}
# Texto: pruebas - Confianza: 99.17% - Tipo: WORD - Coordenadas: {'Width': 0.1571132391691208, 'Height': 0.13604965806007385, 'Left': 0.3487481474876404, 'Top': 0.30097267031669617}
# Texto: de - Confianza: 100.00% - Tipo: WORD - Coordenadas: {'Width': 0.0399305559694767, 'Height': 0.095703125, 'Left': 0.11414928734302521, 'Top': 0.42968741059303284}
# Texto: conocimiento! - Confianza: 93.61% - Tipo: WORD - Coordenadas: {'Width': 0.2832535207271576, 'Height': 0.13172844052314758, 'Left': 0.16740895807743073, 'Top': 0.4106570780277252}
# Texto: EDUCA - Confianza: 99.16% - Tipo: WORD - Coordenadas: {'Width': 0.046875, 'Height': 0.02734375, 'Left': 0.9526909589767456, 'Top': 0.517578125}
# Texto: 16, - Confianza: 100.00% - Tipo: WORD - Coordenadas: {'Width': 0.0360243059694767, 'Height': 0.0517578125, 'Left': 0.1271701157093048, 'Top': 0.6220702528953552}
# Texto: 17 - Confianza: 100.00% - Tipo: WORD - Coordenadas: {'Width': 0.0290798619389534, 'Height': 0.044921875, 'Left': 0.171875, 'Top': 0.6220703125}
# Texto: y - Confianza: 95.99% - Tipo: WORD - Coordenadas: {'Width': 0.01519097201526165, 'Height': 0.0439453125, 'Left': 0.2078993022441864, 'Top': 0.6337890625}
# Texto: 18 - Confianza: 100.00% - Tipo: WORD - Coordenadas: {'Width': 0.0295138880610466, 'Height': 0.0458984375, 'Left': 0.2313368022441864, 'Top': 0.6220703125}
# Texto: de - Confianza: 100.00% - Tipo: WORD - Coordenadas: {'Width': 0.0290798619389534, 'Height': 0.0458984375, 'Left': 0.2686631977558136, 'Top': 0.6220703125}
# Texto: diciembre - Confianza: 99.60% - Tipo: WORD - Coordenadas: {'Width': 0.1184895858168602, 'Height': 0.048828125, 'Left': 0.3051215410232544, 'Top': 0.6201171875}
# Texto: TECH - Confianza: 71.15% - Tipo: WORD - Coordenadas: {'Width': 0.1944444477558136, 'Height': 0.1435546875, 'Left': 0.1792534738779068, 'Top': 0.7744140625}
# Texto: TALENTO - Confianza: 98.36% - Tipo: WORD - Coordenadas: {'Width': 0.1184895858168602, 'Height': 0.0380859375, 'Left': 0.1974826455116272, 'Top': 0.78125}
